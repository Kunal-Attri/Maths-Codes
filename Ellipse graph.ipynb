# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
start = 0
end = 2 * pi
# resolution = pi / 180
# i = start
theta = np.linspace(start, end, 360)

a = 2
b = 3

x = a * np.cos(theta)
y = b * np.sin(theta)



#while i <= end:
#    x.append(a * cos(i))
#    y.append(b * sin(i))
#    i += resolution

# %%
plt.plot(x, y)
plt.grid(True)
plt.show()
